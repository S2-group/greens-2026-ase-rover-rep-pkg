# %% [markdown]
# # Welcome to the Thesis Notebook where measurements are pre-processed, cleaned, plotted and transformed
# ## Here, will be covered the measurements done using powerstat and the energy service + analyser service

# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import re
import numpy as np

# %% [markdown]
# ## Please modify root_path in order to switch experiments (idle or imaging)

# %%
# followed by folders each with their own .txt file
root_path = Path("./data/before_intervention/measurements_idle_state/experiments/battery/")
dir_list = os.listdir(root_path)

# Filter + sort by repetition number
sorted_dirs = sorted(
    [item for item in dir_list if re.match(r"run_0_repetition_(\d+)", item)],
    key=lambda name: int(re.search(r"run_0_repetition_(\d+)", name).group(1))
)

# Print sorted
print(sorted_dirs)
# Out:
# ['run_0_repetition_0', 'run_0_repetition_1', 'run_0_repetition_2', 'run_0_repetition_3', 'run_0_repetition_4', 'run_0_repetition_5', 'run_0_repetition_6', 'run_0_repetition_7', 'run_0_repetition_8', 'run_0_repetition_9', 'run_0_repetition_10', 'run_0_repetition_11', 'run_0_repetition_12', 'run_0_repetition_13', 'run_0_repetition_14', 'run_0_repetition_15', 'run_0_repetition_16', 'run_0_repetition_17', 'run_0_repetition_18', 'run_0_repetition_19', 'run_0_repetition_20', 'run_0_repetition_21', 'run_0_repetition_22', 'run_0_repetition_23', 'run_0_repetition_24', 'run_0_repetition_25', 'run_0_repetition_26', 'run_0_repetition_27', 'run_0_repetition_28', 'run_0_repetition_29']

# %%
# data = pd.read_csv('./data/measurements_idle_state/experiments/new_runner_experiment/run_0_repetition_0/analyser_logs_clean.txt', sep=',')
# # print(data)

# %% [markdown]
# ## Get path for experiment and order it

# %%
all_logs = []

for folder_name in sorted_dirs:
    folder_path = root_path / folder_name
    txt_path = folder_path / "analyser_logs_clean.txt"

    if not txt_path.exists():
        continue  # skip if file doesn't exist
        
    with open(txt_path, "r") as f:
        lines = f.readlines()

        clean_lines = []
        
        for line in lines:
            match = re.search(r"\[(\d{2}:\d{2}:\d{2})\]\s*(EnergySensorOutput.*?)$", line)
            if match:
                timestamp = match.group(1)
                log_data = match.group(2)
                clean_lines.append({
                    "time": timestamp,
                    "data": log_data
                })
        all_logs.append({
            "PATH": txt_path,
            "lines": clean_lines
        })

# print(all_logs)
print(all_logs[4]["PATH"])
all_logs[4]['lines']
# Out:
# data/before_intervention/measurements_idle_state/experiments/battery/run_0_repetition_4/analyser_logs_clean.txt
# [{'time': '14:33:08',
#   'data': 'EnergySensorOutput(supply_voltage=16.174999237060547, current_amps=0.4180000126361847, power_watts=6.75)\x1b'},
#  {'time': '14:33:09',
#   'data': 'EnergySensorOutput(supply_voltage=16.173749923706055, current_amps=0.4300000071525574, power_watts=6.974999904632568)\x1b'},
#  {'time': '14:33:10',
#   'data': 'EnergySensorOutput(supply_voltage=16.174999237060547, current_amps=0.41499999165534973, power_watts=6.724999904632568)\x1b'},
#  {'time': '14:33:11',
#   'data': 'EnergySensorOutput(supply_voltage=16.174999237060547, current_amps=0.4309999942779541, power_watts=6.974999904632568)\x1b'},
#  {'time': '14:33:12',
#   'data': 'EnergySensorOutput(supply_voltage=16.173749923706055, current_amps=0.41600000858306885, power_watts=6.724999904632568)\x1b'},
#  {'time': '14:33:13',
# ...

# %% [markdown]
# ## Convert to dataframe

# %%
records = []

for log in all_logs:
    for entry in log["lines"]:
        records.append({
            "file": log["PATH"].parent.name,
            "timestamp": entry["time"],
            "data": entry["data"]
        })

# %%
df = pd.DataFrame(records)
display(df)
# Out:
#                     file timestamp  \
# 0     run_0_repetition_0  14:30:04
# 1     run_0_repetition_0  14:30:05
# 2     run_0_repetition_0  14:30:06
# 3     run_0_repetition_0  14:30:07
# 4     run_0_repetition_0  14:30:08
# ..                   ...       ...
# 416  run_0_repetition_29  14:52:33
# 417  run_0_repetition_29  14:52:34
# 418  run_0_repetition_29  14:52:35
# 419  run_0_repetition_29  14:52:36
# 420  run_0_repetition_29  14:52:37
#
#                                                   data
# 0    EnergySensorOutput(supply_voltage=16.226249694...
# 1    EnergySensorOutput(supply_voltage=16.226249694...
# 2    EnergySensorOutput(supply_voltage=16.225000381...
# 3    EnergySensorOutput(supply_voltage=16.225000381...
# 4    EnergySensorOutput(supply_voltage=16.223749160...
# ..                                                 ...
# 416  EnergySensorOutput(supply_voltage=15.911250114...
# 417  EnergySensorOutput(supply_voltage=15.911250114...
# ...

# %% [markdown]
# ## Format data into DataFrame, along with voltage, current and power => clean

# %%
def extract_values(data):
    match = re.search(r"supply_voltage=(.*?), current_amps=(.*?), power_watts=(.*?)\)", data)
    if match:
        return float(match.group(1)), float(match.group(2)), float(match.group(3))
    return None, None, None

df[["voltage", "current", "power"]] = df["data"].apply(
    lambda x: pd.Series(extract_values(x))
)
# df.drop('data', axis=1, inplace=True)
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Optional: show all columns
pd.set_option('display.width', None)  # Prevent line wrapping
pd.set_option('display.max_colwidth', None)  # Show full content in each cell
print(df)
# df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 7
# ...

# %% [markdown]
# ## Plot based on each experiment run (30 repetitions per run)

# %%
# STEPS:
# get first col of df
# filter such that the last one or 2 digits of the name represent each run 
# for each filtered df, compute plot for the 3 variables (voltage, current, power) based on timestamp
# types of plots : 
# 1. line chart with a line for each variable plotted against the timestamp
# 2. scatter plot with a color for each variable plotted against the timestamp

# %%
name_run = df['file']
# create new col for repetition nr
df["repetition"] = df["file"].str.extract(r"repetition_(\d+)$").astype(int)
# display(df)

# %% [markdown]
# ## PLOTS

# %% [markdown]
# ### Here are plots for each individual run with their respective timestamps. Please check or change var of repetition for other runs

# %%
# this displays energy measurements per each run
# change to display a different run
run_df = df[df['repetition'] == 12]

# Plot
plt.figure(figsize=(12,6))

plt.plot(run_df['timestamp'], run_df['voltage'], label="Voltage (V)")
plt.plot(run_df['timestamp'], run_df['current'], label="Current (A)")
plt.plot(run_df['timestamp'], run_df['power'], label="Power (W)")

plt.title("Energy Measurements for Run")
plt.xlabel("Timestamp")
plt.ylabel("Measurement Values")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Filter for run 11. Change for other run
run_df = df[df['repetition'] == 8]

# Plot
plt.figure(figsize=(12,6))

plt.scatter(run_df['timestamp'], run_df['voltage'], label="Voltage (V)", marker='o')
plt.scatter(run_df['timestamp'], run_df['current'], label="Current (A)", marker='x')
plt.scatter(run_df['timestamp'], run_df['power'], label="Power (W)", marker='^')

plt.title("Energy Measurements (Scatter) for Run")
plt.xlabel("Timestamp")
plt.ylabel("Measurement Values")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
for rep in df['repetition'].unique():
    subset = df[df['repetition'] == rep]
    plt.plot(subset['timestamp'], subset['power'], label=f"Run {rep}")

# %%
avg_power = df.groupby("repetition")["power"].mean()
avg_power.plot(kind="bar", title="Average Power per Run", ylabel="Power (W)")
# Out:
# <Axes: title={'center': 'Average Power per Run'}, xlabel='repetition', ylabel='Power (W)'>

# %%
plt.figure(figsize=(8, 6))
sc = plt.scatter(df["voltage"], df["current"], c=df["power"], cmap="viridis", alpha=0.7)
plt.xlabel("Voltage (V)")
plt.ylabel("Current (A)")
plt.title("Voltage vs. Current (Colored by Power)")
cbar = plt.colorbar(sc)
cbar.set_label("Power (W)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.kdeplot(data=df, x="power", hue="repetition")
# Out:
# <Axes: xlabel='power', ylabel='Density'>

# %% [markdown]
# ## Shapiro-Wilk test for normality. If p > 0.05, the data is normal.
# 1. In our test below (for the imaging state), this appears to be normal for 28 repetitions, and false only for 2. Based on research, it seems like a good result for energy measurements.
# 2. In our test below (for the idle state), this appears to be a bimodal distribution, with more than 50% of observations counting as not-normal values.

# %%
from scipy.stats import shapiro

for rep in df["repetition"].unique():
    p = shapiro(df[df["repetition"] == rep]["power"])[1]
    print(f"Repetition {rep} normal? {p > 0.05}")
# Out:
# Repetition 0 normal? False
# Repetition 1 normal? False
# Repetition 2 normal? False
# Repetition 3 normal? False
# Repetition 4 normal? False
# Repetition 5 normal? False
# Repetition 6 normal? False
# Repetition 7 normal? True
# Repetition 8 normal? False
# Repetition 9 normal? True
# Repetition 10 normal? True
# Repetition 11 normal? True
# Repetition 12 normal? True
# Repetition 13 normal? True
# Repetition 14 normal? True
# Repetition 15 normal? True
# Repetition 16 normal? False
# Repetition 17 normal? True
# Repetition 18 normal? False
# Repetition 19 normal? False
# Repetition 20 normal? False
# Repetition 21 normal? False
# Repetition 22 normal? False
# Repetition 23 normal? False
# Repetition 24 normal? False
# Repetition 25 normal? False
# Repetition 26 normal? False
# Repetition 27 normal? False
# Repetition 28 normal? False
# Repetition 29 normal? False

# %% [markdown]
# ## Compute average measurements for all logs for each repetition and plot a line chart
# Each repetition 0,1,2 .. has multiple measurements. Here, I compute the average of the measurements per repetition and I plot based on those averages

# %%
# Group by repetition and compute mean for voltage, current, and power
avg_per_run = df.groupby("repetition")[["voltage", "current", "power"]].mean().reset_index()
avg_per_run.head()
# Out:
#    repetition    voltage   current     power
# 0           0  16.224286  0.423786  6.898214
# 1           1  16.211071  0.422286  6.858929
# 2           2  16.198215  0.427429  6.933929
# 3           3  16.185804  0.425500  6.894643
# 4           4  16.173125  0.425429  6.878571

# %%
plt.figure(figsize=(10, 6))

plt.plot(avg_per_run["repetition"], avg_per_run["voltage"], label="Voltage (V)")
plt.plot(avg_per_run["repetition"], avg_per_run["current"], label="Current (A)")
plt.plot(avg_per_run["repetition"], avg_per_run["power"], label="Power (W)")

plt.title("Average Voltage, Current, and Power per Run")
plt.xlabel("Repetition")
plt.ylabel("Average Measurement")
plt.xticks(avg_per_run["repetition"])  # Show all run numbers
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 2. Create X locations
reps = avg_per_run["repetition"].values
space = 3
x = np.arange(len(reps)) * space  # positions on x-axis

# 3. Set bar width
width = 0.6

# 4. Plot bars for each metric
plt.figure(figsize=(16, 8))
plt.bar(x - width, avg_per_run["voltage"], width, label="Voltage (V)", color="tab:blue")
plt.bar(x,         avg_per_run["current"], width, label="Current (A)", color="tab:orange")
plt.bar(x + width, avg_per_run["power"],   width, label="Power (W)",   color="tab:green")

# 5. Add labels and formatting
plt.xlabel("Repetition")
plt.ylabel("Average Value")
plt.title("Average Voltage, Current, and Power per Repetition")
plt.xticks(x, reps)
plt.legend()
# plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Average per experiment
# Now, I take the average of the entire repetitions and compute only one value per variable. Average voltage, current and power

# %%
overall_avg = df[["voltage", "current", "power"]].mean()
display(overall_avg)
# Out:
# voltage    16.061876
# current     0.431888
# power       6.947625
# dtype: float64
